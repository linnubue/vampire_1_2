# %% [markdown]
# ## Instruments on A and Peildeck

# %%
import matplotlib.pyplot as plt
import numpy as np
import os as os
os.environ['PATH_PLOTS'] = ''

# %%
#center of coordinate system is corner on port site towards the bow
## heights are measured to the peildeck or A-Deck, but the Peildeck is 162 cm higher (so this is added later for the legend)

# %%
corner_grawac_bowport = (446, -317)
corner_grawac_bowstar = (446+102, -317)
corner_grawac_sternport = (446, -317-108)
corner_grawac_sternstar = (446+102, -317-108)
grawac_middle_ronde = (446+39.5+12,-317-108+45)
grawac_halter1_start = (446, -317-108+23.5)
grawac_halter1_end = (446, -317-108+29.5)
grawac_halter2_start = (446, -317-108+50.5)
grawac_halter2_end = (446, -317-108+56.5)
grawac_height_stand = 33
grawac_height_center = 91 ## to the beginning of the rondes
grawac_height_top = 91+41

corner_mirac_bowport = (441, -317-108-45.5)
corner_mirac_bowstar = (441+110, -317-108-45.5)
corner_mirac_sternport = (441,  -317-108-45.5-101)
corner_mirac_sternstar = (441+110, -317-108-45.5-101)
mirac_middle_ronde = (441+40+16,-317-108-45.5-101+47)
reling_y =  -317-108-45.5-101-150.5
mirac_height_stand = 49
mirac_height_center = 41.5 + 49  ## to the beginning of the rondes
mirac_height_top = 41.5 + 49 + 26
middle_imu = (441+31, -317-108-45.5-7.5-16.5)
height_imu = 41.5 + 49 +10.5 ##to the top of the pi

parsival_center = (441+110+23, -317-108-45.5-101-150.5+22)
parsival_height = 197 ##to the very top, not to the laser

ultrasonic_center = (441+110+23+113+7, -317-108-45.5-101-150.5+23) ##113 cm between poles but ultrasonic has an extra pole attached, adding 7 cm
ultrasonic_height = 175 ## to the lower part of the frame, see photos

distance_parsival_reling_ADeck = 282
x_reling_ADeck =441+110+23 -282
y_reling_ADeckbow =  -317-108-45.5-101-150.5
y_reling_ADeckstern = y_reling_ADeckbow - (369+64+90+71.5+90+442+465)

flir = (x_reling_ADeck -32, y_reling_ADeckbow -369)
gopro = (x_reling_ADeck -26,flir[1]+6)
height_gopro = 108
height_flir = 110
corner_lhumpro_bowport = (x_reling_ADeck - 42, y_reling_ADeckbow -369-64)
corner_lhumpro_bowstar = (x_reling_ADeck +17, y_reling_ADeckbow -369-64)
corner_lhumpro_sternport = (x_reling_ADeck - 42, y_reling_ADeckbow -369-64-90)
corner_lhumpro_sternstar = (x_reling_ADeck +17, y_reling_ADeckbow -369-64-90)
y_mirror_lhumpro = y_reling_ADeckbow -369-64-67
height_lhumpro_center = 151
height_lhumpro_stand = 125.5 #height of the stands
height_lhumpro_top = 168.5

corner_hatpro_bowport = (x_reling_ADeck - 42, y_reling_ADeckbow -369-64-90-71.5)
corner_hatpro_bowstar = (x_reling_ADeck +17, y_reling_ADeckbow-369-64-90-71.5)
corner_hatpro_sternport = (x_reling_ADeck - 42, y_reling_ADeckbow-369-64-90-71.5-90)
corner_hatpro_sternstar = (x_reling_ADeck +17, y_reling_ADeckbow-369-64-90-71.5-90)
y_mirror_hatpro = y_reling_ADeckbow -369-64-90-71.5-90+67
height_hatpro_center = 151
height_hatpro_stand = 124.5 #height of the stands
height_hatpro_top = 168.5

sky_cam_vis =  (x_reling_ADeck -16, y_reling_ADeckbow-369-64-90-71.5-90-43)
sky_cam_ir =  (x_reling_ADeck -16, y_reling_ADeckbow -369-64-90-71.5-90-55.5)
height_skycam = 111

miniimu = (x_reling_ADeck+55, y_reling_ADeckstern+(50))
height_miniimu = -(188-9.5-11)##distance to A-Deck
##position GPS trimble 2:
gps_trimble2 = (x_reling_ADeck+17, reling_y +42)
height_trimble2 = 306 #3.06 m from Peildeck, plus the distance to A deck

# %%
# %matplotlib inline
fig = plt.figure(figsize=(7.5,6))
ax = fig.add_subplot()
ax.grid()

ax.plot([0, 0], [0,reling_y], c="black")
ax.plot([0, 1100], [reling_y,reling_y], c="black")
ax.plot([x_reling_ADeck,x_reling_ADeck], [y_reling_ADeckbow,y_reling_ADeckstern], c="black")
ax.plot([x_reling_ADeck,2000], [y_reling_ADeckstern,y_reling_ADeckstern], c="black")
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
colors = np.append(colors, ["grey"])
for grawac_coords in [corner_grawac_bowport, corner_grawac_bowstar, corner_grawac_sternport, corner_grawac_sternstar]:
    ax.scatter(grawac_coords[0],grawac_coords[1], c=colors[0] , s=5 )
for mirac_coords in [corner_mirac_bowport, corner_mirac_bowstar, corner_mirac_sternport, corner_mirac_sternstar]:
    ax.scatter(mirac_coords[0],mirac_coords[1], c=colors[1]  , s=5 )
ax.plot([corner_grawac_bowport[0], corner_grawac_bowstar[0], corner_grawac_sternstar[0], corner_grawac_sternport[0],corner_grawac_bowport[0]],
        [corner_grawac_bowport[1], corner_grawac_bowstar[1], corner_grawac_sternstar[1], corner_grawac_sternport[1],corner_grawac_bowport[1]], 
        label=f"GRaWAC (height: {grawac_height_top +162:.1f} cm)")

ax.plot([grawac_halter1_start[0],grawac_halter1_end[0]], [grawac_halter1_start[1], grawac_halter1_end[1]], c="grey", lw=2)
ax.plot([grawac_halter2_start[0],grawac_halter2_end[0]], [grawac_halter2_start[1], grawac_halter2_end[1]], c="grey", lw=2)
ax.scatter(grawac_middle_ronde[0], grawac_middle_ronde[1],marker= "x", c=colors[0])
ax.scatter(mirac_middle_ronde[0], mirac_middle_ronde[1],marker= "x", c=colors[1])

ax.plot([corner_mirac_bowport[0], corner_mirac_bowstar[0], corner_mirac_sternstar[0], corner_mirac_sternport[0],corner_mirac_bowport[0]],
        [corner_mirac_bowport[1], corner_mirac_bowstar[1], corner_mirac_sternstar[1], corner_mirac_sternport[1],corner_mirac_bowport[1]], c=colors[1],
        label=f"MiRAC-A (height: {mirac_height_top +162:.1f} cm)")
ax.scatter(middle_imu[0], middle_imu[1],marker = "s", label=f"", c="white", s=14)

ax.scatter(middle_imu[0], middle_imu[1],marker = "s", label=f"IMU Raspberry (height: {height_imu +162:.1f} cm)", c=colors[2], s=12)
ax.scatter(parsival_center[0], parsival_center[1], marker = "x", lw=2.5,
           label = f"", color="white") #height to top
ax.scatter(parsival_center[0], parsival_center[1], marker = "x", 
           label = f"Parsivel (height: {parsival_height+162:.1f} cm)", color=colors[3]) #height to top
ax.scatter(ultrasonic_center[0], ultrasonic_center[1], marker = "x",  color="white", lw=2.5,
           label = f"") #to lower part of frame

ax.scatter(ultrasonic_center[0], ultrasonic_center[1], marker = "x",  color=colors[4],
           label = f"Ultrasonic (height: {ultrasonic_height+162:.1f} cm)") #to lower part of frame

for hatpro_coords in [corner_hatpro_bowport, corner_hatpro_bowstar, corner_hatpro_sternport, corner_hatpro_sternstar]:
    ax.scatter(hatpro_coords[0],hatpro_coords[1], c=colors[5] , s=5 )
for mirac_coords in [corner_lhumpro_bowport, corner_lhumpro_bowstar, corner_lhumpro_sternport, corner_lhumpro_sternstar]:
    ax.scatter(mirac_coords[0],mirac_coords[1], c=colors[6]  , s=5 )

ax.plot([corner_hatpro_bowport[0], corner_hatpro_bowstar[0], corner_hatpro_sternstar[0], corner_hatpro_sternport[0],corner_hatpro_bowport[0]],
        [corner_hatpro_bowport[1], corner_hatpro_bowstar[1], corner_hatpro_sternstar[1], corner_hatpro_sternport[1], corner_hatpro_bowport[1]],
        c=colors[5] ,label=f"HATPRO (height: {height_hatpro_top:.1f} cm)")
ax.plot([corner_hatpro_bowport[0],corner_hatpro_bowstar[0]], [y_mirror_hatpro,y_mirror_hatpro], "-", color=colors[5]) ##mirror estimate
ax.plot([corner_lhumpro_bowport[0], corner_lhumpro_bowstar[0], corner_lhumpro_sternstar[0], corner_lhumpro_sternport[0],corner_lhumpro_bowport[0]],
        [corner_lhumpro_bowport[1], corner_lhumpro_bowstar[1], corner_lhumpro_sternstar[1], corner_lhumpro_sternport[1], corner_lhumpro_bowport[1]], 
        c=colors[6], label=f"MiRAC-P (height: {height_lhumpro_top:.1f} cm)")
ax.plot([corner_lhumpro_bowport[0],corner_lhumpro_bowstar[0]], [y_mirror_lhumpro,y_mirror_lhumpro], "-", color=colors[6]) ##mirror estimate


ax.scatter(gopro[0], gopro[1], marker = "_", lw=2.5,
           label = f"", color="white")
ax.scatter(gopro[0], gopro[1], marker = "_", lw=2,
           label = f"GoPro (height: {height_gopro:.1f} cm)", color=colors[7])
ax.scatter(flir[0], flir[1], marker = "_",  color="white",lw=2.5,
           label = f"")
ax.scatter(flir[0], flir[1], marker = "_",  color=colors[8],
           label = f"FLIR (height: {height_flir:.1f} cm)")
ax.scatter(sky_cam_vis[0], sky_cam_vis[1], marker = "s", s=22, color="white",
           label = f"")
ax.scatter(sky_cam_vis[0], sky_cam_vis[1], marker = "s",  color=colors[9],
           label = f"Sky camera (height: {height_skycam:.1f} cm)")


ax.scatter(miniimu[0], miniimu[1], marker = "o",  color=colors[10],
           label = f"Mini-IMU (height: {height_miniimu:.1f} cm)")
ax.scatter(gps_trimble2[0], gps_trimble2[1], marker = "d",  color="red",
           label = f"GPS trimble 2 (height: {height_trimble2+162:.1f} cm)")

#ax.scatter(sky_cam_ir[0], sky_cam_ir[1], marker = "s",  color="lightblue",
 #          label = f"Sky camera IR (height: {height_skycam} cm)")
ax.plot([0, 2000], [0,0], c="black")
ax.text(650, -300, "Peildeck", color="black", fontsize=12,
 bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.5'))
ax.text(650, -1000, "A-Deck", color="black", fontsize=12, bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.5'))

ax.legend(bbox_to_anchor=(1.1, 0.5), title="Instruments\n(all heights relative to A-Deck)", fancybox=True)#loc="lower right")#
ax.set_aspect("equal")
ax.set_xlim(-100, 1250)
ax.set_xlabel("Distance (cm)", fontsize=12)
ax.set_ylabel("Distance (cm)", fontsize=12)
print("all heights relative to A-Deck")
#fig.patch.set_facecolor((1, 1, 1, 0.5))
plt.savefig(f"{os.environ['PATH_PLOTS']}instrument_positions_withtrimble_v1.png", bbox_inches="tight", dpi=300, transparent=False)
# Out:
# all heights relative to A-Deck
